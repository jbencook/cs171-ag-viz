# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shapely.geometry as geom
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-7a3f7c03c9c6> in <module>()
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import shapely.geometry as geom
#
# //anaconda/lib/python2.7/site-packages/shapely/geometry/__init__.py in <module>()
#       2 """
#       3
# ----> 4 from .base import CAP_STYLE, JOIN_STYLE
#       5 from .geo import box, shape, asShape, mapping
#       6 from .point import Point, asPoint
#
# //anaconda/lib/python2.7/site-packages/shapely/geometry/base.py in <module>()
#       7 from ctypes import pointer, c_size_t, c_char_p, c_void_p
#       8
# ----> 9 from shapely.coords import CoordinateSequence
#      10 from shapely.ftools import wraps
#      11 from shapely.geos import lgeos, ReadingError
#
# //anaconda/lib/python2.7/site-packages/shapely/coords.py in <module>()
# ...

# %%
# !ls
# Out:
# Filter_County_Data.ipynb         local_yields
# area-yield_04042014.csv          nebraska.geojson
# compress_gdd.ipynb               nwcc-station_03312014.csv
# county_03312014.csv              nwcc_03312014.csv
# county_yield_1910_2013.csv       price.csv
# county_yield_1980_2013.csv       state_03312014.csv
# county_yield_small_1910_2013.csv station_03312014.csv
# filter_local_yield.ipynb         us-named.json
# gdd.json                         wmk5_2009_small.csv
# local-yield_04042014.csv

# %%
# !head wmk5_2009_small.csv
# Out:
# ,lat,lon,yld,yld_ordinal,elevation,mukey,soil
# 72,41.25002213043478,-97.14781307246376,168.64476395490112,3.0,1624.0157,1691306,"Olbut-Butler silt loams, 0 to 1 percent slopes"
# 73,41.25002213043478,-97.14772560869565,167.1789818665427,3.0,1623.3596,1691306,"Olbut-Butler silt loams, 0 to 1 percent slopes"
# 74,41.25002213043478,-97.14763814492754,167.4821573954488,3.0,1624.0157,1691306,"Olbut-Butler silt loams, 0 to 1 percent slopes"
# 75,41.25002213043478,-97.14755068115942,167.1959550667679,3.0,1624.3438,1691306,"Olbut-Butler silt loams, 0 to 1 percent slopes"
# 76,41.25002213043478,-97.1474632173913,166.06023119511553,3.0,1624.3438,1691277,"Fillmore silt loam, occasionally ponded"
# 77,41.25002213043478,-97.14737575362318,164.02095901504936,2.0,1624.3438,1691277,"Fillmore silt loam, occasionally ponded"
# 78,41.25002213043478,-97.14728828985507,161.16602319804116,2.0,1625.9843,1691277,"Fillmore silt loam, occasionally ponded"
# ...

# %%
wmk = pd.read_csv("local_yields/wmk1_2009.csv")

# %%
data = wmk.loc[np.random.randint(0, len(wmk), 2000)]

# %%
plt.plot(data.lon, data.lat, '.')
